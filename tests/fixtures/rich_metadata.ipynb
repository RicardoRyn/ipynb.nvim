# %% [markdown]
# # Notebook with Rich Metadata
#
# Testing metadata preservation.

# %%
print('hello')
# Out:
# hello

# %%
emoji = '🎉'
japanese = '日本語'
math = '∫∑∏'

# %%
# Cell with trailing newline
x = 1
